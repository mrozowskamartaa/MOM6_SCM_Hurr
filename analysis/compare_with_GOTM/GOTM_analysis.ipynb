# %%
import xarray as xr

# %%
ds = xr.open_dataset('/gpfs/f5/gfdl_o/scratch/Marta.Mrozowska/hurricane_LES/MOM6_SCM_Hurr/analysis/compare_with_GOTM/cases/001.nc')
ds = ds.isel(lat=0,lon=0)

# %%
ds
# Out:
# <xarray.Dataset> Size: 203MB
# Dimensions:     (time: 2593, z: 300, zi: 301)
# Coordinates:
#   * time        (time) datetime64[ns] 21kB 2011-04-01 ... 2011-04-04
#     lon         float32 4B 0.0
#     lat         float32 4B 27.84
#     z           (time, z) float32 3MB ...
#     zi          (time, zi) float32 3MB ...
# Data variables: (12/105)
#     rho_p       (time, z) float32 3MB ...
#     rho         (time, z) float32 3MB ...
#     zeta        (time) float32 10kB ...
#     u_taus      (time) float32 10kB ...
#     Hice        (time) float32 10kB ...
#     u10         (time) float32 10kB ...
#     ...          ...
#     us0         (time) float32 10kB ...
#     vs0         (time) float32 10kB ...
#     ds          (time) float32 10kB ...
#     Ekin        (time) float32 10kB ...
#     Epot        (time) float32 10kB ...
#     Eturb       (time) float32 10kB ...
# Attributes:
#     title:    HURR_LES
#     comment:  file created by flexout - https://github.com/BoldingBruggeman/f...

# %%
ds.tauy.T[-1].plot()
